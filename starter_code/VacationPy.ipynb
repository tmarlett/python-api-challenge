# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import gmaps.datasets
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Load from CSV
csv_input = "../output_data/City_Data.csv"
initialDF = pd.read_csv(csv_input)
initialDF
# Out:
#     Unnamed: 0                 Name  Latitude  Longitude  Max Temp  Humidity  \
# 0            0             Tasiilaq     65.61     -37.64    276.15        93
# 1            1               Ōmachi     36.50     137.87    295.93        83
# 2            2                Kapaa     22.08    -159.32    303.15        70
# 3            3             Souillac    -20.52      57.52    293.15        60
# 4            4            Busselton    -33.65     115.33    279.26        80
# 5            5            Upernavik     72.79     -56.15    280.89        77
# 6            6             Thompson     55.74     -97.86    302.15        54
# 7            7               Atuona     -9.80    -139.03    299.56        75
# 8            8              Shawnee     39.05     -95.77    305.15        59
# 9            9                Arlit     18.74       7.39    307.18        35
# 10          10              Mataura    -46.19     168.86    277.04        83
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Create Humidity DataFrame
humidityDF = initialDF[['Latitude','Longitude','Humidity']]
humidityData = humidityDF.to_dict()

# Configure gmaps
gmaps.configure(api_key=g_key)
m = gmaps.Map()
try:
    heatmap_layer = gmaps.heatmap_layer(humidityDF[['Latitude','Longitude']],
                                        weights=humidityDF['Humidity'],
                                        max_intensity=150,
                                        point_radius=10.0)
    m.add_layer(heatmap_layer)
except:
    print("You come to the depressing realization that this code does not work.")
m
# Out:
# Map(configuration={'api_key': 'AIzaSyDB4J-6sML4PfxkUNgq211HZGYz-YtjDww'}, data_bounds=[(-53.83132382164568, -1…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
